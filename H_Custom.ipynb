# %%
import tensorflow as tf
import keras
import cv2
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, ZeroPadding2D
from keras.losses import categorical_crossentropy
from keras.optimizers import SGD, Adam
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau, TensorBoard, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

#------------------------------
#cpu - gpu configuration
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True)) 
keras.backend.set_session(sess)
#------------------------------
#variables
height = 48
width = 48
num_classes = 7 #angry, disgust, fear, happy, sad, surprise, neutral
batch_size = 64
epochs = 1000
#------------------------------
#read kaggle facial expression recognition challenge dataset (fer2013.csv)
#https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge

with open("../images/fer2013/fer2013.csv") as f:
    content = f.readlines()

lines = np.array(content)

num_of_instances = lines.size
print("number of instances: ",num_of_instances)
print("instance length: ",len(lines[1].split(",")[1].split(" ")))

#------------------------------
#initialize trainset and test set
x_train, y_train, x_test, y_test = [], [], [], []

#------------------------------
#transfer train and test set data
for i in range(1,num_of_instances):
    try:
        emotion, img, usage = lines[i].split(",")
          
        val = img.split(" ")
            
        pixels = np.array(val, 'float32')
        #pixels = cv2.resize(pixels,(width,height))
        
        emotion = keras.utils.to_categorical(emotion, num_classes)
    
        if 'Training' in usage:
            y_train.append(emotion)
            x_train.append(pixels)
        elif 'PublicTest' in usage:
            y_test.append(emotion)
            x_test.append(pixels)
    except:
        print("",end="")

#------------------------------
#data transformation for train and test sets
x_train = np.array(x_train, 'float32')
y_train = np.array(y_train, 'float32')
x_test = np.array(x_test, 'float32')
y_test = np.array(y_test, 'float32')

x_train_mean = np.mean(x_train)
x_train_std = np.std(x_train)
x_test_mean = np.mean(x_test)
x_test_std = np.std(x_test)
x_train -= x_train_mean
x_test -= x_test_mean
x_train /= x_train_std 
x_test /= x_test_std

x_train = x_train.reshape(x_train.shape[0], width, height, 1)
x_train = x_train.astype('float32')
x_test = x_test.reshape(x_test.shape[0], width, height, 1)
x_test = x_test.astype('float32')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# /home/connor/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# number of instances:  35888
# instance length:  2304
# 28709 train samples
# 3589 test samples

# %%
model = Sequential()

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', input_shape=(width, height, 1), data_format='channels_last', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Flatten())

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_classes, activation='softmax'))


gen = ImageDataGenerator()
val_gen = ImageDataGenerator()
train_generator = gen.flow(x_train, y_train, batch_size=batch_size, shuffle=True)
valid_generator = val_gen.flow(x_test, y_test, batch_size=batch_size)

model.compile(loss=categorical_crossentropy,
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
              metrics=['accuracy'])

model.summary()

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.75, patience=3, verbose=1)

early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=6, verbose=1, mode='auto')

checkpointer = ModelCheckpoint('../models/MODEL_H.h5', monitor='val_acc', verbose=1, save_best_only=True)

tensorboard = TensorBoard(log_dir='../logs/H')

steps_train = train_generator.n//train_generator.batch_size
steps_valid = valid_generator.n//valid_generator.batch_size
history = model.fit_generator(train_generator, 
                                  steps_per_epoch=steps_train, 
                                  validation_steps = steps_valid,
                                  epochs=epochs, 
                                  validation_data=valid_generator,
                                  callbacks=[early_stopper, checkpointer, tensorboard])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 256)       295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 12, 12, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 512)         1180160
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              4719616
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 10,468,295
# Trainable params: 10,464,455
# Non-trainable params: 3,840
# _________________________________________________________________
# Epoch 1/1000
# 448/448 [==============================] - 51s 114ms/step - loss: 2.3815 - acc: 0.2155 - val_loss: 1.8022 - val_acc: 0.2559
#
# Epoch 00001: val_acc improved from -inf to 0.25586, saving model to ../models/MODEL_Turkey4.h5
# Epoch 2/1000
# 448/448 [==============================] - 40s 90ms/step - loss: 1.7866 - acc: 0.2734 - val_loss: 1.7120 - val_acc: 0.2965
#
# Epoch 00002: val_acc improved from 0.25586 to 0.29645, saving model to ../models/MODEL_Turkey4.h5
# Epoch 3/1000
# 448/448 [==============================] - 40s 89ms/step - loss: 1.6868 - acc: 0.3149 - val_loss: 1.5705 - val_acc: 0.3892
#
# Epoch 00003: val_acc improved from 0.29645 to 0.38922, saving model to ../models/MODEL_Turkey4.h5
# Epoch 4/1000
# 448/448 [==============================] - 38s 85ms/step - loss: 1.5896 - acc: 0.3666 - val_loss: 1.4918 - val_acc: 0.4065
#
# Epoch 00004: val_acc improved from 0.38922 to 0.40652, saving model to ../models/MODEL_Turkey4.h5
# Epoch 5/1000
# 448/448 [==============================] - 38s 86ms/step - loss: 1.5168 - acc: 0.3989 - val_loss: 1.4873 - val_acc: 0.4221
#
# Epoch 00005: val_acc improved from 0.40652 to 0.42213, saving model to ../models/MODEL_Turkey4.h5
# Epoch 6/1000
# 448/448 [==============================] - 39s 86ms/step - loss: 1.4694 - acc: 0.4165 - val_loss: 1.4110 - val_acc: 0.4448
#
# Epoch 00006: val_acc improved from 0.42213 to 0.44482, saving model to ../models/MODEL_Turkey4.h5
# Epoch 7/1000
# 448/448 [==============================] - 39s 86ms/step - loss: 1.4411 - acc: 0.4274 - val_loss: 1.3945 - val_acc: 0.4326
#
# Epoch 00007: val_acc did not improve from 0.44482
# Epoch 8/1000
# 448/448 [==============================] - 39s 86ms/step - loss: 1.4227 - acc: 0.4330 - val_loss: 1.4501 - val_acc: 0.4508
#
# Epoch 00008: val_acc improved from 0.44482 to 0.45078, saving model to ../models/MODEL_Turkey4.h5
# Epoch 9/1000
# 448/448 [==============================] - 39s 86ms/step - loss: 1.4033 - acc: 0.4314 - val_loss: 1.4469 - val_acc: 0.4298
#
# Epoch 00009: val_acc did not improve from 0.45078
# Epoch 10/1000
# 448/448 [==============================] - 38s 85ms/step - loss: 1.3777 - acc: 0.4473 - val_loss: 1.3399 - val_acc: 0.4607
#
# Epoch 00010: val_acc improved from 0.45078 to 0.46071, saving model to ../models/MODEL_Turkey4.h5
# Epoch 11/1000
# 448/448 [==============================] - 38s 85ms/step - loss: 1.3639 - acc: 0.4620 - val_loss: 1.3117 - val_acc: 0.4911
#
# Epoch 00011: val_acc improved from 0.46071 to 0.49106, saving model to ../models/MODEL_Turkey4.h5
# Epoch 12/1000
# 448/448 [==============================] - 38s 85ms/step - loss: 1.3387 - acc: 0.4802 - val_loss: 1.3026 - val_acc: 0.5004
#
# Epoch 00012: val_acc improved from 0.49106 to 0.50043, saving model to ../models/MODEL_Turkey4.h5
# Epoch 13/1000
# 448/448 [==============================] - 40s 89ms/step - loss: 1.2944 - acc: 0.4921 - val_loss: 1.2743 - val_acc: 0.5152
#
# Epoch 00013: val_acc improved from 0.50043 to 0.51518, saving model to ../models/MODEL_Turkey4.h5
# Epoch 14/1000
# 448/448 [==============================] - 39s 87ms/step - loss: 1.2817 - acc: 0.5052 - val_loss: 1.2770 - val_acc: 0.5070
#
# Epoch 00014: val_acc did not improve from 0.51518
# Epoch 15/1000
# 448/448 [==============================] - 39s 87ms/step - loss: 1.2508 - acc: 0.5212 - val_loss: 1.1730 - val_acc: 0.5478
#
# Epoch 00015: val_acc improved from 0.51518 to 0.54780, saving model to ../models/MODEL_Turkey4.h5
# Epoch 16/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 1.2171 - acc: 0.5360 - val_loss: 1.2252 - val_acc: 0.5552
#
# Epoch 00016: val_acc improved from 0.54780 to 0.55518, saving model to ../models/MODEL_Turkey4.h5
# Epoch 17/1000
# 448/448 [==============================] - 39s 87ms/step - loss: 1.2214 - acc: 0.5429 - val_loss: 1.2218 - val_acc: 0.5427
#
# Epoch 00017: val_acc did not improve from 0.55518
# Epoch 18/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 1.1686 - acc: 0.5667 - val_loss: 1.1601 - val_acc: 0.5623
#
# Epoch 00018: val_acc improved from 0.55518 to 0.56227, saving model to ../models/MODEL_Turkey4.h5
# Epoch 19/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 1.1414 - acc: 0.5740 - val_loss: 1.1063 - val_acc: 0.5901
#
# Epoch 00019: val_acc improved from 0.56227 to 0.59007, saving model to ../models/MODEL_Turkey4.h5
# Epoch 20/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 1.1166 - acc: 0.5875 - val_loss: 1.1286 - val_acc: 0.5779
#
# Epoch 00020: val_acc did not improve from 0.59007
# Epoch 21/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 1.0945 - acc: 0.5962 - val_loss: 1.1288 - val_acc: 0.5838
#
# Epoch 00021: val_acc did not improve from 0.59007
# Epoch 22/1000
# 448/448 [==============================] - 40s 90ms/step - loss: 1.0780 - acc: 0.6047 - val_loss: 1.0516 - val_acc: 0.6054
#
# Epoch 00022: val_acc improved from 0.59007 to 0.60539, saving model to ../models/MODEL_Turkey4.h5
# Epoch 23/1000
# 448/448 [==============================] - 40s 88ms/step - loss: 1.0850 - acc: 0.6056 - val_loss: 1.3060 - val_acc: 0.5092
#
# Epoch 00023: val_acc did not improve from 0.60539
# Epoch 24/1000
# 448/448 [==============================] - 39s 87ms/step - loss: 1.0748 - acc: 0.6062 - val_loss: 1.0363 - val_acc: 0.6165
#
# Epoch 00024: val_acc improved from 0.60539 to 0.61645, saving model to ../models/MODEL_Turkey4.h5
# Epoch 25/1000
# 448/448 [==============================] - 39s 87ms/step - loss: 1.0229 - acc: 0.6297 - val_loss: 1.0612 - val_acc: 0.6077
#
# Epoch 00025: val_acc did not improve from 0.61645
# Epoch 26/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 0.9899 - acc: 0.6362 - val_loss: 1.0619 - val_acc: 0.6074
#
# Epoch 00026: val_acc did not improve from 0.61645
# Epoch 27/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 0.9574 - acc: 0.6513 - val_loss: 1.0424 - val_acc: 0.6184
#
# Epoch 00027: val_acc improved from 0.61645 to 0.61844, saving model to ../models/MODEL_Turkey4.h5
# Epoch 28/1000
# 448/448 [==============================] - 40s 90ms/step - loss: 0.9855 - acc: 0.6455 - val_loss: 1.0590 - val_acc: 0.6179
#
# Epoch 00028: val_acc did not improve from 0.61844
# Epoch 29/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 0.9241 - acc: 0.6653 - val_loss: 1.0336 - val_acc: 0.6355
#
# Epoch 00029: val_acc improved from 0.61844 to 0.63546, saving model to ../models/MODEL_Turkey4.h5
# Epoch 30/1000
# 448/448 [==============================] - 40s 89ms/step - loss: 0.9445 - acc: 0.6582 - val_loss: 1.1099 - val_acc: 0.5915
#
# Epoch 00030: val_acc did not improve from 0.63546
# Epoch 31/1000
# 448/448 [==============================] - 40s 88ms/step - loss: 0.9057 - acc: 0.6731 - val_loss: 1.0336 - val_acc: 0.6298
#
# Epoch 00031: val_acc did not improve from 0.63546
# Epoch 32/1000
# 448/448 [==============================] - 39s 87ms/step - loss: 0.9001 - acc: 0.6792 - val_loss: 1.0228 - val_acc: 0.6165
#
# Epoch 00032: val_acc did not improve from 0.63546
# Epoch 33/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 0.9015 - acc: 0.6809 - val_loss: 1.0525 - val_acc: 0.6179
#
# Epoch 00033: val_acc did not improve from 0.63546
# Epoch 34/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 0.8790 - acc: 0.6867 - val_loss: 1.0429 - val_acc: 0.6329
#
# Epoch 00034: val_acc did not improve from 0.63546
# Epoch 35/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 0.8507 - acc: 0.6931 - val_loss: 1.0300 - val_acc: 0.6383
#
# Epoch 00035: val_acc improved from 0.63546 to 0.63830, saving model to ../models/MODEL_Turkey4.h5
# Epoch 36/1000
# 448/448 [==============================] - 40s 90ms/step - loss: 0.8125 - acc: 0.7083 - val_loss: 1.0323 - val_acc: 0.6420
#
# Epoch 00036: val_acc improved from 0.63830 to 0.64199, saving model to ../models/MODEL_Turkey4.h5
# Epoch 37/1000
# 448/448 [==============================] - 39s 87ms/step - loss: 0.8089 - acc: 0.7106 - val_loss: 1.0423 - val_acc: 0.6258
#
# Epoch 00037: val_acc did not improve from 0.64199
# Epoch 38/1000
# 448/448 [==============================] - 39s 87ms/step - loss: 0.8009 - acc: 0.7151 - val_loss: 1.0314 - val_acc: 0.6445
#
# Epoch 00038: val_acc improved from 0.64199 to 0.64454, saving model to ../models/MODEL_Turkey4.h5
# Epoch 39/1000
# 448/448 [==============================] - 39s 87ms/step - loss: 0.7734 - acc: 0.7258 - val_loss: 1.0867 - val_acc: 0.6352
#
# Epoch 00039: val_acc did not improve from 0.64454
# Epoch 40/1000
# 448/448 [==============================] - 39s 86ms/step - loss: 0.7879 - acc: 0.7217 - val_loss: 1.0391 - val_acc: 0.6428
#
# Epoch 00040: val_acc did not improve from 0.64454
# Epoch 41/1000
# 448/448 [==============================] - 38s 86ms/step - loss: 0.7625 - acc: 0.7300 - val_loss: 1.0844 - val_acc: 0.6338
#
# Epoch 00041: val_acc did not improve from 0.64454
# Epoch 42/1000
# 448/448 [==============================] - 38s 86ms/step - loss: 0.7629 - acc: 0.7316 - val_loss: 1.0981 - val_acc: 0.6235
#
# Epoch 00042: val_acc did not improve from 0.64454
# Epoch 43/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 0.7641 - acc: 0.7323 - val_loss: 1.1758 - val_acc: 0.6026
#
# Epoch 00043: val_acc did not improve from 0.64454
# Epoch 44/1000
# 448/448 [==============================] - 39s 88ms/step - loss: 0.7379 - acc: 0.7392 - val_loss: 1.0802 - val_acc: 0.6332
#
# Epoch 00044: val_acc did not improve from 0.64454
# Epoch 00044: early stopping

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'y',linewidth=3.0)
plt.plot(history.history['val_loss'],'g',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Accuracy curves
plt.figure(figsize=[8,6])
plt.plot(history.history['acc'],'r',linewidth=3.0)
plt.plot(history.history['val_acc'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5,1,'Accuracy Curves')
