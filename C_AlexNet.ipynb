# %%
import tensorflow as tf
import keras
import cv2
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, ZeroPadding2D
from keras.losses import categorical_crossentropy
from keras.optimizers import SGD, Adam
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau, TensorBoard, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

#------------------------------
#cpu - gpu configuration
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True)) 
keras.backend.set_session(sess)
#------------------------------
#variables
height = 48
width = 48
num_classes = 7 #angry, disgust, fear, happy, sad, surprise, neutral
batch_size = 64
epochs = 1000
#------------------------------
#read kaggle facial expression recognition challenge dataset (fer2013.csv)
#https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge

with open("../images/fer2013/fer2013.csv") as f:
    content = f.readlines()

lines = np.array(content)

num_of_instances = lines.size
print("number of instances: ",num_of_instances)
print("instance length: ",len(lines[1].split(",")[1].split(" ")))

#------------------------------
#initialize trainset and test set
x_train, y_train, x_test, y_test = [], [], [], []

#------------------------------
#transfer train and test set data
for i in range(1,num_of_instances):
    try:
        emotion, img, usage = lines[i].split(",")
          
        val = img.split(" ")
            
        pixels = np.array(val, 'float32')
        
        emotion = keras.utils.to_categorical(emotion, num_classes)
    
        if 'Training' in usage:
            y_train.append(emotion)
            x_train.append(pixels)
        elif 'PublicTest' in usage:
            y_test.append(emotion)
            x_test.append(pixels)
    except:
        print("",end="")

#------------------------------
#data transformation for train and test sets
x_train = np.array(x_train, 'float32')
y_train = np.array(y_train, 'float32')
x_test = np.array(x_test, 'float32')
y_test = np.array(y_test, 'float32')

x_train_mean = np.mean(x_train)
x_train_std = np.std(x_train)
x_test_mean = np.mean(x_test)
x_test_std = np.std(x_test)
x_train -= x_train_mean
x_test -= x_test_mean
x_train /= x_train_std 
x_test /= x_test_std

x_train = x_train.reshape(x_train.shape[0], width, height, 1)
x_train = x_train.astype('float32')
x_test = x_test.reshape(x_test.shape[0], width, height, 1)
x_test = x_test.astype('float32')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# /home/connor/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# number of instances:  35888
# instance length:  2304
# 28709 train samples
# 3589 test samples

# %%
model = Sequential()

model.add(Conv2D(96, (5,5), input_shape=(width,height ,1), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=2))

model.add(Conv2D(256, (5,5), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=2))

model.add(Conv2D(384, (5,5), activation='relu', padding='same'))
model.add(Conv2D(384, (5,5), activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=2))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))


gen = ImageDataGenerator()
val_gen = ImageDataGenerator()
train_generator = gen.flow(x_train, y_train, batch_size=batch_size, shuffle=True)
valid_generator = val_gen.flow(x_test, y_test, batch_size=batch_size)

model.compile(loss=categorical_crossentropy,
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),#SGD(lr = 0.01, momentum=0.9),
              metrics=['accuracy'])

model.summary()

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.75, patience=3, verbose=1)

early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=11, verbose=1, mode='auto')

checkpointer = ModelCheckpoint('../models/MODEL_AlexNet_f.h5', monitor='val_acc', verbose=1, save_best_only=True)

tensorboard = TensorBoard(log_dir='../logs/AlexNet_f')

steps_train = train_generator.n//train_generator.batch_size
steps_valid = valid_generator.n//valid_generator.batch_size
history = model.fit_generator(train_generator, 
                                  steps_per_epoch=steps_train, 
                                  validation_steps = steps_valid,
                                  epochs=epochs, 
                                  validation_data=valid_generator,
                                  callbacks=[early_stopper, checkpointer, tensorboard])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 96)        2496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 96)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 23, 23, 256)       614656
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 384)       2457984
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 384)       3686784
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 256)       884992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              26218496
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 28679
# =================================================================
# Total params: 50,675,399
# Trainable params: 50,675,399
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 448/448 [==============================] - 63s 140ms/step - loss: 1.7919 - acc: 0.2614 - val_loss: 1.6504 - val_acc: 0.3248
#
# Epoch 00001: val_acc improved from -inf to 0.32478, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 2/1000
# 448/448 [==============================] - 63s 141ms/step - loss: 1.5540 - acc: 0.3834 - val_loss: 1.4466 - val_acc: 0.4420
#
# Epoch 00002: val_acc improved from 0.32478 to 0.44199, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 3/1000
# 448/448 [==============================] - 62s 138ms/step - loss: 1.4255 - acc: 0.4447 - val_loss: 1.3595 - val_acc: 0.4729
#
# Epoch 00003: val_acc improved from 0.44199 to 0.47291, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 4/1000
# 448/448 [==============================] - 63s 142ms/step - loss: 1.3477 - acc: 0.4766 - val_loss: 1.3359 - val_acc: 0.4806
#
# Epoch 00004: val_acc improved from 0.47291 to 0.48057, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 5/1000
# 448/448 [==============================] - 64s 142ms/step - loss: 1.2849 - acc: 0.5033 - val_loss: 1.2975 - val_acc: 0.4888
#
# Epoch 00005: val_acc improved from 0.48057 to 0.48879, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 6/1000
# 448/448 [==============================] - 63s 141ms/step - loss: 1.2345 - acc: 0.5285 - val_loss: 1.2653 - val_acc: 0.5248
#
# Epoch 00006: val_acc improved from 0.48879 to 0.52482, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 7/1000
# 448/448 [==============================] - 63s 141ms/step - loss: 1.1860 - acc: 0.5447 - val_loss: 1.2605 - val_acc: 0.5163
#
# Epoch 00007: val_acc did not improve from 0.52482
# Epoch 8/1000
# 448/448 [==============================] - 63s 141ms/step - loss: 1.1363 - acc: 0.5653 - val_loss: 1.2967 - val_acc: 0.5223
#
# Epoch 00008: val_acc did not improve from 0.52482
# Epoch 9/1000
# 448/448 [==============================] - 63s 141ms/step - loss: 1.0839 - acc: 0.5860 - val_loss: 1.2338 - val_acc: 0.5279
#
# Epoch 00009: val_acc improved from 0.52482 to 0.52794, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 10/1000
# 448/448 [==============================] - 64s 142ms/step - loss: 1.0262 - acc: 0.6112 - val_loss: 1.2541 - val_acc: 0.5302
#
# Epoch 00010: val_acc improved from 0.52794 to 0.53021, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 11/1000
# 448/448 [==============================] - 63s 141ms/step - loss: 0.9791 - acc: 0.6317 - val_loss: 1.2829 - val_acc: 0.5359
#
# Epoch 00011: val_acc improved from 0.53021 to 0.53589, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 12/1000
# 448/448 [==============================] - 63s 141ms/step - loss: 0.9180 - acc: 0.6525 - val_loss: 1.3275 - val_acc: 0.5311
#
# Epoch 00012: val_acc did not improve from 0.53589
# Epoch 13/1000
# 448/448 [==============================] - 63s 141ms/step - loss: 0.8550 - acc: 0.6803 - val_loss: 1.3284 - val_acc: 0.5396
#
# Epoch 00013: val_acc improved from 0.53589 to 0.53957, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 14/1000
# 448/448 [==============================] - 63s 141ms/step - loss: 0.7861 - acc: 0.7082 - val_loss: 1.3804 - val_acc: 0.5308
#
# Epoch 00014: val_acc did not improve from 0.53957
# Epoch 15/1000
# 448/448 [==============================] - 63s 141ms/step - loss: 0.7334 - acc: 0.7286 - val_loss: 1.4386 - val_acc: 0.5367
#
# Epoch 00015: val_acc did not improve from 0.53957
# Epoch 16/1000
# 448/448 [==============================] - 63s 140ms/step - loss: 0.6812 - acc: 0.7519 - val_loss: 1.4153 - val_acc: 0.5396
#
# Epoch 00016: val_acc did not improve from 0.53957
# Epoch 17/1000
# 448/448 [==============================] - 62s 139ms/step - loss: 0.6109 - acc: 0.7745 - val_loss: 1.5007 - val_acc: 0.5382
#
# Epoch 00017: val_acc did not improve from 0.53957
# Epoch 18/1000
# 448/448 [==============================] - 61s 137ms/step - loss: 0.5639 - acc: 0.7960 - val_loss: 1.5624 - val_acc: 0.5418
#
# Epoch 00018: val_acc improved from 0.53957 to 0.54184, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 19/1000
# 448/448 [==============================] - 60s 133ms/step - loss: 0.5215 - acc: 0.8150 - val_loss: 1.7317 - val_acc: 0.5305
#
# Epoch 00019: val_acc did not improve from 0.54184
# Epoch 20/1000
# 448/448 [==============================] - 61s 135ms/step - loss: 0.4895 - acc: 0.8253 - val_loss: 1.8078 - val_acc: 0.5282
#
# Epoch 00020: val_acc did not improve from 0.54184
# Epoch 21/1000
# 448/448 [==============================] - 59s 131ms/step - loss: 0.4592 - acc: 0.8395 - val_loss: 1.6552 - val_acc: 0.5384
#
# Epoch 00021: val_acc did not improve from 0.54184
# Epoch 22/1000
# 448/448 [==============================] - 60s 134ms/step - loss: 0.4063 - acc: 0.8599 - val_loss: 1.8227 - val_acc: 0.5379
#
# Epoch 00022: val_acc did not improve from 0.54184
# Epoch 23/1000
# 448/448 [==============================] - 60s 133ms/step - loss: 0.3904 - acc: 0.8646 - val_loss: 1.7707 - val_acc: 0.5333
#
# Epoch 00023: val_acc did not improve from 0.54184
# Epoch 24/1000
# 448/448 [==============================] - 59s 132ms/step - loss: 0.3713 - acc: 0.8755 - val_loss: 1.9898 - val_acc: 0.5438
#
# Epoch 00024: val_acc improved from 0.54184 to 0.54383, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 25/1000
# 448/448 [==============================] - 58s 130ms/step - loss: 0.3546 - acc: 0.8812 - val_loss: 1.9733 - val_acc: 0.5404
#
# Epoch 00025: val_acc did not improve from 0.54383
# Epoch 26/1000
# 448/448 [==============================] - 58s 129ms/step - loss: 0.3441 - acc: 0.8841 - val_loss: 2.0130 - val_acc: 0.5353
#
# Epoch 00026: val_acc did not improve from 0.54383
# Epoch 27/1000
# 448/448 [==============================] - 59s 132ms/step - loss: 0.3105 - acc: 0.8987 - val_loss: 1.9434 - val_acc: 0.5481
#
# Epoch 00027: val_acc improved from 0.54383 to 0.54809, saving model to ../models/MODEL_AlexNet_f.h5
# Epoch 28/1000
# 448/448 [==============================] - 60s 134ms/step - loss: 0.3136 - acc: 0.8998 - val_loss: 2.0430 - val_acc: 0.5401
#
# Epoch 00028: val_acc did not improve from 0.54809
# Epoch 29/1000
# 448/448 [==============================] - 60s 133ms/step - loss: 0.3055 - acc: 0.8993 - val_loss: 1.9605 - val_acc: 0.5211
#
# Epoch 00029: val_acc did not improve from 0.54809
# Epoch 30/1000
# 448/448 [==============================] - 60s 134ms/step - loss: 0.2648 - acc: 0.9146 - val_loss: 1.9538 - val_acc: 0.5279
#
# Epoch 00030: val_acc did not improve from 0.54809
# Epoch 31/1000
# 448/448 [==============================] - 60s 133ms/step - loss: 0.2708 - acc: 0.9144 - val_loss: 2.0512 - val_acc: 0.5313
#
# Epoch 00031: val_acc did not improve from 0.54809
# Epoch 32/1000
# 448/448 [==============================] - 59s 131ms/step - loss: 0.2698 - acc: 0.9149 - val_loss: 2.1870 - val_acc: 0.5189
#
# Epoch 00032: val_acc did not improve from 0.54809
# Epoch 33/1000
# 448/448 [==============================] - 59s 131ms/step - loss: 0.2963 - acc: 0.9078 - val_loss: 2.0623 - val_acc: 0.5382
#
# Epoch 00033: val_acc did not improve from 0.54809
# Epoch 34/1000
# 448/448 [==============================] - 59s 132ms/step - loss: 0.2590 - acc: 0.9191 - val_loss: 2.1024 - val_acc: 0.5404
#
# Epoch 00034: val_acc did not improve from 0.54809
# Epoch 35/1000
# 448/448 [==============================] - 61s 136ms/step - loss: 0.2712 - acc: 0.9159 - val_loss: 2.1974 - val_acc: 0.5277
#
# Epoch 00035: val_acc did not improve from 0.54809
# Epoch 36/1000
# 448/448 [==============================] - 61s 135ms/step - loss: 0.2516 - acc: 0.9215 - val_loss: 2.0727 - val_acc: 0.5438
#
# Epoch 00036: val_acc did not improve from 0.54809
# Epoch 37/1000
# 448/448 [==============================] - 60s 133ms/step - loss: 0.2506 - acc: 0.9233 - val_loss: 1.9639 - val_acc: 0.5226
#
# Epoch 00037: val_acc did not improve from 0.54809
# Epoch 38/1000
# 448/448 [==============================] - 59s 131ms/step - loss: 0.2713 - acc: 0.9186 - val_loss: 2.0427 - val_acc: 0.5274
#
# Epoch 00038: val_acc did not improve from 0.54809
# Epoch 00038: early stopping

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'y',linewidth=3.0)
plt.plot(history.history['val_loss'],'g',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Accuracy curves
plt.figure(figsize=[8,6])
plt.plot(history.history['acc'],'r',linewidth=3.0)
plt.plot(history.history['val_acc'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5,1,'Accuracy Curves')
