# %%
import tensorflow as tf
import keras
import cv2
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, ZeroPadding2D
from keras.losses import categorical_crossentropy
from keras.optimizers import SGD, Adam
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau, TensorBoard, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

#------------------------------
#cpu - gpu configuration
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True)) 
keras.backend.set_session(sess)
#------------------------------
#variables
height = 48
width = 48
num_classes = 7 #angry, disgust, fear, happy, sad, surprise, neutral
batch_size = 64
epochs = 1000
#------------------------------
#read kaggle facial expression recognition challenge dataset (fer2013.csv)
#https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge

with open("../images/fer2013/fer2013.csv") as f:
    content = f.readlines()

lines = np.array(content)

num_of_instances = lines.size
print("number of instances: ",num_of_instances)
print("instance length: ",len(lines[1].split(",")[1].split(" ")))

#------------------------------
#initialize trainset and test set
x_train, y_train, x_test, y_test = [], [], [], []

#------------------------------
#transfer train and test set data
for i in range(1,num_of_instances):
    try:
        emotion, img, usage = lines[i].split(",")
          
        val = img.split(" ")
            
        pixels = np.array(val, 'float32')
        #pixels = cv2.resize(pixels,(width,height))
        
        emotion = keras.utils.to_categorical(emotion, num_classes)
    
        if 'Training' in usage:
            y_train.append(emotion)
            x_train.append(pixels)
        elif 'PublicTest' in usage:
            y_test.append(emotion)
            x_test.append(pixels)
    except:
        print("",end="")

#------------------------------
#data transformation for train and test sets
x_train = np.array(x_train, 'float32')
y_train = np.array(y_train, 'float32')
x_test = np.array(x_test, 'float32')
y_test = np.array(y_test, 'float32')

x_train_mean = np.mean(x_train)
x_train_std = np.std(x_train)
x_test_mean = np.mean(x_test)
x_test_std = np.std(x_test)
x_train -= x_train_mean
x_test -= x_test_mean
x_train /= x_train_std 
x_test /= x_test_std

x_train = x_train.reshape(x_train.shape[0], width, height, 1)
x_train = x_train.astype('float32')
x_test = x_test.reshape(x_test.shape[0], width, height, 1)
x_test = x_test.astype('float32')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# /home/connor/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# number of instances:  35888
# instance length:  2304
# 28709 train samples
# 3589 test samples

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), input_shape=(width,height ,1), padding='same', activation='relu'))
model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), strides=2))

model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), strides=2))

model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), strides=2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))


gen = ImageDataGenerator()
val_gen = ImageDataGenerator()
train_generator = gen.flow(x_train, y_train, batch_size=batch_size, shuffle=True)
valid_generator = val_gen.flow(x_test, y_test, batch_size=batch_size)

model.compile(loss=categorical_crossentropy,
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),#SGD(lr = 0.01, momentum=0.9),
              metrics=['accuracy'])

model.summary()

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.75, patience=3, verbose=1)

early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=11, verbose=1, mode='auto')

checkpointer = ModelCheckpoint('../models/MODEL_Existing_f.h5', monitor='val_acc', verbose=1, save_best_only=True)

tensorboard = TensorBoard(log_dir='../logs/Existing_f')

steps_train = train_generator.n//train_generator.batch_size
steps_valid = valid_generator.n//valid_generator.batch_size
history = model.fit_generator(train_generator, 
                                  steps_per_epoch=steps_train, 
                                  validation_steps = steps_valid,
                                  epochs=epochs, 
                                  validation_data=valid_generator,
                                  callbacks=[early_stopper, checkpointer, tensorboard])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 1,585,255
# Trainable params: 1,585,255
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 448/448 [==============================] - 18s 41ms/step - loss: 1.6437 - acc: 0.3420 - val_loss: 1.4064 - val_acc: 0.4643
#
# Epoch 00001: val_acc improved from -inf to 0.46429, saving model to ../models/MODEL_Existing_f.h5
# Epoch 2/1000
# 448/448 [==============================] - 9s 21ms/step - loss: 1.3388 - acc: 0.4848 - val_loss: 1.2211 - val_acc: 0.5206
#
# Epoch 00002: val_acc improved from 0.46429 to 0.52057, saving model to ../models/MODEL_Existing_f.h5
# Epoch 3/1000
# 448/448 [==============================] - 9s 21ms/step - loss: 1.2041 - acc: 0.5395 - val_loss: 1.1751 - val_acc: 0.5506
#
# Epoch 00003: val_acc improved from 0.52057 to 0.55064, saving model to ../models/MODEL_Existing_f.h5
# Epoch 4/1000
# 448/448 [==============================] - 9s 21ms/step - loss: 1.1207 - acc: 0.5755 - val_loss: 1.1236 - val_acc: 0.5762
#
# Epoch 00004: val_acc improved from 0.55064 to 0.57617, saving model to ../models/MODEL_Existing_f.h5
# Epoch 5/1000
# 448/448 [==============================] - 9s 21ms/step - loss: 1.0467 - acc: 0.6033 - val_loss: 1.1221 - val_acc: 0.5730
#
# Epoch 00005: val_acc did not improve from 0.57617
# Epoch 6/1000
# 448/448 [==============================] - 9s 21ms/step - loss: 0.9698 - acc: 0.6329 - val_loss: 1.1452 - val_acc: 0.5759
#
# Epoch 00006: val_acc did not improve from 0.57617
# Epoch 7/1000
# 448/448 [==============================] - 9s 21ms/step - loss: 0.9022 - acc: 0.6607 - val_loss: 1.1401 - val_acc: 0.5833
#
# Epoch 00007: val_acc improved from 0.57617 to 0.58326, saving model to ../models/MODEL_Existing_f.h5
# Epoch 8/1000
# 448/448 [==============================] - 10s 21ms/step - loss: 0.8260 - acc: 0.6913 - val_loss: 1.1700 - val_acc: 0.5875
#
# Epoch 00008: val_acc improved from 0.58326 to 0.58752, saving model to ../models/MODEL_Existing_f.h5
# Epoch 9/1000
# 448/448 [==============================] - 9s 21ms/step - loss: 0.7562 - acc: 0.7176 - val_loss: 1.1471 - val_acc: 0.5892
#
# Epoch 00009: val_acc improved from 0.58752 to 0.58922, saving model to ../models/MODEL_Existing_f.h5
# Epoch 10/1000
# 448/448 [==============================] - 9s 21ms/step - loss: 0.6949 - acc: 0.7396 - val_loss: 1.2369 - val_acc: 0.6006
#
# Epoch 00010: val_acc improved from 0.58922 to 0.60057, saving model to ../models/MODEL_Existing_f.h5
# Epoch 11/1000
# 448/448 [==============================] - 10s 21ms/step - loss: 0.6341 - acc: 0.7634 - val_loss: 1.2538 - val_acc: 0.5861
#
# Epoch 00011: val_acc did not improve from 0.60057
# Epoch 12/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.5795 - acc: 0.7824 - val_loss: 1.2855 - val_acc: 0.5949
#
# Epoch 00012: val_acc did not improve from 0.60057
# Epoch 13/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.5390 - acc: 0.7991 - val_loss: 1.3863 - val_acc: 0.5915
#
# Epoch 00013: val_acc did not improve from 0.60057
# Epoch 14/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.4991 - acc: 0.8167 - val_loss: 1.3845 - val_acc: 0.5847
#
# Epoch 00014: val_acc did not improve from 0.60057
# Epoch 15/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.4535 - acc: 0.8347 - val_loss: 1.4653 - val_acc: 0.5974
#
# Epoch 00015: val_acc did not improve from 0.60057
# Epoch 16/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.4225 - acc: 0.8451 - val_loss: 1.5499 - val_acc: 0.5818
#
# Epoch 00016: val_acc did not improve from 0.60057
# Epoch 17/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.4024 - acc: 0.8551 - val_loss: 1.5339 - val_acc: 0.6068
#
# Epoch 00017: val_acc improved from 0.60057 to 0.60681, saving model to ../models/MODEL_Existing_f.h5
# Epoch 18/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.3666 - acc: 0.8690 - val_loss: 1.5911 - val_acc: 0.5918
#
# Epoch 00018: val_acc did not improve from 0.60681
# Epoch 19/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.3496 - acc: 0.8738 - val_loss: 1.6194 - val_acc: 0.5878
#
# Epoch 00019: val_acc did not improve from 0.60681
# Epoch 20/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.3297 - acc: 0.8829 - val_loss: 1.6384 - val_acc: 0.5904
#
# Epoch 00020: val_acc did not improve from 0.60681
# Epoch 21/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.3259 - acc: 0.8838 - val_loss: 1.6783 - val_acc: 0.5940
#
# Epoch 00021: val_acc did not improve from 0.60681
# Epoch 22/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.3199 - acc: 0.8872 - val_loss: 1.7063 - val_acc: 0.6043
#
# Epoch 00022: val_acc did not improve from 0.60681
# Epoch 23/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.2987 - acc: 0.8941 - val_loss: 1.7758 - val_acc: 0.5790
#
# Epoch 00023: val_acc did not improve from 0.60681
# Epoch 24/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.2955 - acc: 0.8963 - val_loss: 1.7139 - val_acc: 0.5980
#
# Epoch 00024: val_acc did not improve from 0.60681
# Epoch 25/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.2724 - acc: 0.9029 - val_loss: 1.8009 - val_acc: 0.5918
#
# Epoch 00025: val_acc did not improve from 0.60681
# Epoch 26/1000
# 448/448 [==============================] - 10s 23ms/step - loss: 0.2732 - acc: 0.9021 - val_loss: 1.7819 - val_acc: 0.5952
#
# Epoch 00026: val_acc did not improve from 0.60681
# Epoch 27/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.2620 - acc: 0.9071 - val_loss: 1.7879 - val_acc: 0.5932
#
# Epoch 00027: val_acc did not improve from 0.60681
# Epoch 28/1000
# 448/448 [==============================] - 10s 22ms/step - loss: 0.2545 - acc: 0.9108 - val_loss: 1.8397 - val_acc: 0.5983
#
# Epoch 00028: val_acc did not improve from 0.60681
# Epoch 00028: early stopping

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'y',linewidth=3.0)
plt.plot(history.history['val_loss'],'g',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Accuracy curves
plt.figure(figsize=[8,6])
plt.plot(history.history['acc'],'r',linewidth=3.0)
plt.plot(history.history['val_acc'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5,1,'Accuracy Curves')
